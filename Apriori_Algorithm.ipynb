# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/DataSets')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd

# %%
df = pd.read_excel('Online_Retail.xlsx')

# %%
df.head(4)
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
#
# [4 rows x 9 columns]

# %%
# Data cleaning, includes removing spaces from some of the Description and drop the rules that do not have InvoiceNo and remove the grade 
# transactions because that is no use to us

df['Description'] = df['Description'].str.strip()
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [532621 rows x 9 columns]

# %%
# We need to consolidate the items into one transaction per row with each product, 
# for the sake of keeping the dataset small we are only looking at the sales for France

basket = (df[df['Country'] == 'France'].groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                          0.0  ...                              0.0
# 536852                          0.0  ...                              0.0
# 536974                          0.0  ...                              0.0
# 537065                          0.0  ...                              0.0
# 537463                          0.0  ...                              0.0
# ...                             ...  ...                              ...
# 580986                          0.0  ...                              0.0
# 581001                          0.0  ...                              0.0
# 581171                          0.0  ...                              0.0
# 581279                          0.0  ...                              0.0
# 581587                          0.0  ...                              0.0
#
# [392 rows x 1563 columns]

# %%
# Now there are a lot of zeros in the data but we also need to make sure any positive values are converted to 1 and anything less than 0 is set to 0

def encode_units(x):
	if x <= 0:
		return 0
	if x >= 1:
		return 1
basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)
basket_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# 580986                            0  ...                                0
# 581001                            0  ...                                0
# 581171                            0  ...                                0
# 581279                            0  ...                                0
# 581587                            0  ...                                0
#
# [392 rows x 1562 columns]

# %%
# We are going to generate frequent itemsets that have support at least 7%
# Now this number is chosen so that you can get close enough and generate the rules with the corresponding support, confidence and lift.
frequent_itemsets = apriori(basket_sets, min_support=0.07, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules.head()
# Out:
#                     antecedents  ... conviction
# 0  (ALARM CLOCK BAKELIKE GREEN)  ...   3.791383
# 1   (ALARM CLOCK BAKELIKE PINK)  ...   3.283859
# 2  (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 3    (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 4   (ALARM CLOCK BAKELIKE PINK)  ...   3.293135
#
# [5 rows x 9 columns]

# %%
rules[(rules["lift"] >= 6)&(rules['confidence'] >= 0.8)]
# Out:
#                                           antecedents  ... conviction
# 2                        (ALARM CLOCK BAKELIKE GREEN)  ...   4.916181
# 3                          (ALARM CLOCK BAKELIKE RED)  ...   5.568878
# 16                    (SET/6 RED SPOTTY PAPER PLATES)  ...   4.336735
# 18                      (SET/6 RED SPOTTY PAPER CUPS)  ...   7.852041
# 19                    (SET/6 RED SPOTTY PAPER PLATES)  ...  21.556122
# 20  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...  ...  34.897959
# 21  (SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY...  ...   4.625850
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...  ...  34.489796
#
# [8 rows x 9 columns]

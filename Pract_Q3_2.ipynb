# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# import os
# os.chdir('/content/drive/My Drive/Colab Notebooks/DataSets/')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
read_data = pd.read_csv('wine.csv')

# %%
read_data.hist(column=read_data.columns[1:], figsize=(12,12));

plt.tight_layout();

# %%
for i in range(1, read_data.shape[1]):
    print(f"{read_data.columns[i]} ::\nMean : {read_data[read_data.columns[i]].mean()}\nStandard Deviation : {read_data[read_data.columns[i]].std()}\n")
# Out:
# Alcohol ::
# Mean : 13.000617977528083
# Standard Deviation : 0.8118265380058577
#
# Malic.acid ::
# Mean : 2.336348314606741
# Standard Deviation : 1.1171460976144627
#
# Ash ::
# Mean : 2.3665168539325854
# Standard Deviation : 0.2743440090608148
#
# Acl ::
# Mean : 19.49494382022472
# Standard Deviation : 3.3395637671735052
#
# Mg ::
# Mean : 99.74157303370787
# Standard Deviation : 14.282483515295668
#
# Phenols ::
# Mean : 2.295112359550562
# Standard Deviation : 0.6258510488339891
#
# Flavanoids ::
# Mean : 2.0292696629213474
# Standard Deviation : 0.9988586850169465
#
# Nonflavanoid.phenols ::
# Mean : 0.36185393258426973
# Standard Deviation : 0.12445334029667939
#
# Proanth ::
# Mean : 1.5908988764044953
# Standard Deviation : 0.5723588626747611
#
# Color.int ::
# Mean : 5.058089882022473
# Standard Deviation : 2.318285871822413
#
# Hue ::
# Mean : 0.9574494382022468
# Standard Deviation : 0.22857156582982338
#
# OD ::
# Mean : 2.6116853932584254
# ...

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
std_scaler

read_data.iloc[:, 1:] = pd.DataFrame(std_scaler.fit_transform(read_data.iloc[:, 1:]), columns=read_data.columns[1:])
read_data
# Out:
#      Wine   Alcohol  Malic.acid       Ash       Acl        Mg   Phenols  \
# 0       1  1.518613   -0.562250  0.232053 -1.169593  1.913905  0.808997
# 1       1  0.246290   -0.499413 -0.827996 -2.490847  0.018145  0.568648
# 2       1  0.196879    0.021231  1.109334 -0.268738  0.088358  0.808997
# 3       1  1.691550   -0.346811  0.487926 -0.809251  0.930918  2.491446
# 4       1  0.295700    0.227694  1.840403  0.451946  1.281985  0.808997
# ..    ...       ...         ...       ...       ...       ...       ...
# 173     3  0.876275    2.974543  0.305159  0.301803 -0.332922 -0.985614
# 174     3  0.493343    1.412609  0.414820  1.052516  0.158572 -0.793334
# 175     3  0.332758    1.744744 -0.389355  0.151661  1.422412 -1.129824
# 176     3  0.209232    0.227694  0.012732  0.151661  1.422412 -1.033684
# 177     3  1.395086    1.583165  1.365208  1.502943 -0.262708 -0.392751
#
#      Flavanoids  Nonflavanoid.phenols   Proanth  Color.int       Hue  \
# ...

# %%
for i in range(1, read_data.shape[1]):
    print(f"{read_data.columns[i]} ::\nMean : {int(np.round(read_data[read_data.columns[i]].mean()))}\nStandard Deviation : {int(np.round(read_data[read_data.columns[i]].std()))}\n")
# Out:
# Alcohol ::
# Mean : 0
# Standard Deviation : 1
#
# Malic.acid ::
# Mean : 0
# Standard Deviation : 1
#
# Ash ::
# Mean : 0
# Standard Deviation : 1
#
# Acl ::
# Mean : 0
# Standard Deviation : 1
#
# Mg ::
# Mean : 0
# Standard Deviation : 1
#
# Phenols ::
# Mean : 0
# Standard Deviation : 1
#
# Flavanoids ::
# Mean : 0
# Standard Deviation : 1
#
# Nonflavanoid.phenols ::
# Mean : 0
# Standard Deviation : 1
#
# Proanth ::
# Mean : 0
# Standard Deviation : 1
#
# Color.int ::
# Mean : 0
# Standard Deviation : 1
#
# Hue ::
# Mean : 0
# Standard Deviation : 1
#
# OD ::
# Mean : 0
# Standard Deviation : 1
#
# Proline ::
# Mean : 0
# Standard Deviation : 1

# %%
read_data.hist(column=read_data.columns[1:], figsize=(12,12));

plt.tight_layout();

# %%
read_data2 = pd.read_csv('iris.csv')

# %%
read_data2.hist(column=read_data2.columns, figsize=(12,12));

plt.tight_layout();

# %%
for i in range(read_data2.shape[1]-1):
    print(f"{read_data2.columns[i]} ::\nMean : {read_data2[read_data2.columns[i]].mean()}\nStandard Deviation : {read_data2[read_data2.columns[i]].std()}\n")
# Out:
# sepal_length ::
# Mean : 5.843333333333335
# Standard Deviation : 0.8280661279778629
#
# sepal_width ::
# Mean : 3.0540000000000007
# Standard Deviation : 0.4335943113621737
#
# petal_length ::
# Mean : 3.7586666666666693
# Standard Deviation : 1.7644204199522617
#
# petal_width ::
# Mean : 1.1986666666666672
# Standard Deviation : 0.7631607417008414

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler().fit(read_data2.iloc[:, :-1])
std_scaler

# read_data.iloc[:, 1:] = pd.DataFrame(std_scaler.fit_transform(read_data.iloc[:, 1:]), columns=read_data.columns[1:])
read_data2.iloc[:, :-1] = std_scaler.transform(read_data2.iloc[:, :-1])
read_data2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0       -0.900681     1.032057     -1.341272    -1.312977     setosa
# 1       -1.143017    -0.124958     -1.341272    -1.312977     setosa
# 2       -1.385353     0.337848     -1.398138    -1.312977     setosa
# 3       -1.506521     0.106445     -1.284407    -1.312977     setosa
# 4       -1.021849     1.263460     -1.341272    -1.312977     setosa
# ..            ...          ...           ...          ...        ...
# 145      1.038005    -0.124958      0.819624     1.447956  virginica
# 146      0.553333    -1.281972      0.705893     0.922064  virginica
# 147      0.795669    -0.124958      0.819624     1.053537  virginica
# 148      0.432165     0.800654      0.933356     1.447956  virginica
# 149      0.068662    -0.124958      0.762759     0.790591  virginica
#
# [150 rows x 5 columns]

# %%
for i in range(read_data2.shape[1]-1):
    print(f"{read_data2.columns[i]} ::\nMean : {int(np.round(read_data2[read_data2.columns[i]].mean()))}\nStandard Deviation : {int(np.round(read_data2[read_data2.columns[i]].std()))}\n")
# Out:
# sepal_length ::
# Mean : 0
# Standard Deviation : 1
#
# sepal_width ::
# Mean : 0
# Standard Deviation : 1
#
# petal_length ::
# Mean : 0
# Standard Deviation : 1
#
# petal_width ::
# Mean : 0
# Standard Deviation : 1

# %%
read_data2.hist(column=read_data2.columns, figsize=(12,12));

plt.tight_layout();

# %%
read_data3 = pd.read_csv('iris.csv')

# %%
# The maximum absolute scaling :- Method_1

# apply the maximum absolute scaling in Pandas using the .abs() and .max() methods
def maximum_absolute_scaling(df):
    # apply maximum absolute scaling
    for column in df.columns:
        df[column] = df[column]  / df[column].abs().max()
    return df
    
# call the maximum_absolute_scaling function

read_data3.iloc[:, :-1] = maximum_absolute_scaling(read_data3.iloc[:, :-1])
read_data3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.645570     0.795455      0.202899         0.08     setosa
# 1        0.620253     0.681818      0.202899         0.08     setosa
# 2        0.594937     0.727273      0.188406         0.08     setosa
# 3        0.582278     0.704545      0.217391         0.08     setosa
# 4        0.632911     0.818182      0.202899         0.08     setosa
# ..            ...          ...           ...          ...        ...
# 145      0.848101     0.681818      0.753623         0.92  virginica
# 146      0.797468     0.568182      0.724638         0.76  virginica
# 147      0.822785     0.681818      0.753623         0.80  virginica
# 148      0.784810     0.772727      0.782609         0.92  virginica
# 149      0.746835     0.681818      0.739130         0.72  virginica
#
# [150 rows x 5 columns]

# %%
# The maximum absolute scaling :- Method_2

from sklearn.preprocessing import MaxAbsScaler

# calculate the maximum absolute value for scaling the data using the fit method
max_abs_scal = MaxAbsScaler().fit(read_data3.iloc[:, :-1])

# the maximum absolute values calculated by the fit method
max_abs_scal.max_abs_
# array([4.0e+05, 1.7e+01])

# transform the data using the parameters calculated by the fit method (the maximum absolute values)
read_data3.iloc[:, :-1] = max_abs_scal.transform(read_data3.iloc[:, :-1])

read_data3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.645570     0.795455      0.202899         0.08     setosa
# 1        0.620253     0.681818      0.202899         0.08     setosa
# 2        0.594937     0.727273      0.188406         0.08     setosa
# 3        0.582278     0.704545      0.217391         0.08     setosa
# 4        0.632911     0.818182      0.202899         0.08     setosa
# ..            ...          ...           ...          ...        ...
# 145      0.848101     0.681818      0.753623         0.92  virginica
# 146      0.797468     0.568182      0.724638         0.76  virginica
# 147      0.822785     0.681818      0.753623         0.80  virginica
# 148      0.784810     0.772727      0.782609         0.92  virginica
# 149      0.746835     0.681818      0.739130         0.72  virginica
#
# [150 rows x 5 columns]

# %%
# The Min-Max features scaling :- Method_1

# apply the min-max scaling in Pandas using the .min() and .max() methods
def min_max_scaling(df):
    # apply min-max scaling
    for column in df.columns:
        df[column] = (df[column] - df[column].min()) / (df[column].max() - df[column].min())
        
    return df
    
# call the min_max_scaling function
read_data3.iloc[:, :-1] = min_max_scaling(read_data3.iloc[:, :-1])

read_data3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.222222     0.625000      0.067797     0.041667     setosa
# 1        0.166667     0.416667      0.067797     0.041667     setosa
# 2        0.111111     0.500000      0.050847     0.041667     setosa
# 3        0.083333     0.458333      0.084746     0.041667     setosa
# 4        0.194444     0.666667      0.067797     0.041667     setosa
# ..            ...          ...           ...          ...        ...
# 145      0.666667     0.416667      0.711864     0.916667  virginica
# 146      0.555556     0.208333      0.677966     0.750000  virginica
# 147      0.611111     0.416667      0.711864     0.791667  virginica
# 148      0.527778     0.583333      0.745763     0.916667  virginica
# 149      0.444444     0.416667      0.694915     0.708333  virginica
#
# [150 rows x 5 columns]

# %%
# The Min-Max features scaling :- Method_2

from sklearn.preprocessing import MinMaxScaler

# create a scaler object
scaler = MinMaxScaler()
# fit and transform the data
read_data3.iloc[:, :-1] = scaler.fit_transform(read_data3.iloc[:, :-1])

read_data3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.222222     0.625000      0.067797     0.041667     setosa
# 1        0.166667     0.416667      0.067797     0.041667     setosa
# 2        0.111111     0.500000      0.050847     0.041667     setosa
# 3        0.083333     0.458333      0.084746     0.041667     setosa
# 4        0.194444     0.666667      0.067797     0.041667     setosa
# ..            ...          ...           ...          ...        ...
# 145      0.666667     0.416667      0.711864     0.916667  virginica
# 146      0.555556     0.208333      0.677966     0.750000  virginica
# 147      0.611111     0.416667      0.711864     0.791667  virginica
# 148      0.527778     0.583333      0.745763     0.916667  virginica
# 149      0.444444     0.416667      0.694915     0.708333  virginica
#
# [150 rows x 5 columns]

# %%
# Robust Scaling
"""
In robust scaling, we scale each feature of the data set by subtracting the median and then dividing by 
the interquartile range. The interquartile range (IQR) is defined as the difference between the third and 
the first quartile and represents the central 50% of the data.

This method comes in handy when working with data sets that contain many outliers because it uses statistics 
that are robust to outliers (median and interquartile range), in contrast with the previous scalers, 
which use statistics that are highly affected by outliers such as the maximum, the minimum, the mean, and the 
standard deviation.

"""
# Out:
# '\nIn robust scaling, we scale each feature of the data set by subtracting the median and then dividing by \nthe interquartile range. The interquartile range (IQR) is defined as the difference between the third and \nthe first quartile and represents the central 50% of the data.\n\nThis method comes in handy when working with data sets that contain many outliers because it uses statistics \nthat are robust to outliers (median and interquartile range), in contrast with the previous scalers, \nwhich use statistics that are highly affected by outliers such as the maximum, the minimum, the mean, and the \nstandard deviation.\n\n'

# %%
# Let’s see how outliers affect the results after scaling the data with min-max scaling and robust scaling.

# The following data set contains 10 data points, one of them being an outlier (variable1 = 30).

# the data frame contains one outlier
df_data = pd.DataFrame({'variable1':[1,2,3,4,5,6,7,30], 'variable2':[1,2,3,4,5,6,7,8]})

df_data
# Out:
#    variable1  variable2
# 0          1          1
# 1          2          2
# 2          3          3
# 3          4          4
# 4          5          5
# 5          6          6
# 6          7          7
# 7         30          8

# %%
"""
The min-max scaling shifts the variable 1 towards 0 due to the presence of an outlier as compared 
with variable 2 where the points are evenly distributed in a range from 0 to 1.
"""
# Out:
# '\nThe min-max scaling shifts the variable 1 towards 0 due to the presence of an outlier as compared \nwith variable 2 where the points are evenly distributed in a range from 0 to 1.\n'

# %%
# The Min-Max features scaling :- Method_2

from sklearn.preprocessing import MinMaxScaler

# create a scaler object
scaler = MinMaxScaler()
# fit and transform the data
df_min_max = pd.DataFrame(scaler.fit_transform(df_data), columns=df_data.columns)

print(df_min_max)


# scatter plot of the data after applying min-max scaling
plt.scatter(df_min_max.iloc[:, 0], df_min_max.iloc[:, 1], s=100, color='blue')

# xticks and yticks
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# labels and title
plt.xlabel('variable1', fontsize=14)
plt.ylabel('variable2', fontsize=14)
plt.title('The min-max scaling', fontsize=20)
# Out:
#    variable1  variable2
# 0   0.000000   0.000000
# 1   0.034483   0.142857
# 2   0.068966   0.285714
# 3   0.103448   0.428571
# 4   0.137931   0.571429
# 5   0.172414   0.714286
# 6   0.206897   0.857143
# 7   1.000000   1.000000
# Text(0.5, 1.0, 'The min-max scaling')

# %%
"""
Before scaling, the first data point has a value of (1,1), both variable 1 and variable 2 have equal values. 
Once transformed, the value of variable 2 is much larger than variable 1 (0.034,0.142). This is because variable 1 
has an outlier.

On the contrary, if we apply robust scaling, both variables have the same values (-1.00,-1.00) after the 
transformation, because both features have the same median and interquartile range, being the outlier the value 
that is shifted.
"""
# Out:
# '\nBefore scaling, the first data point has a value of (1,1), both variable 1 and variable 2 have equal values. \nOnce transformed, the value of variable 2 is much larger than variable 1 (0.034,0.142). This is because variable 1 \nhas an outlier.\n\nOn the contrary, if we apply robust scaling, both variables have the same values (-1.00,-1.00) after the \ntransformation, because both features have the same median and interquartile range, being the outlier the value \nthat is shifted.\n'

# %%
# Robust Scaling :- Method_1

# apply the robust scaling in Pandas using the .median() and .quantile() methods
def robust_scaling(df):
    # copy the dataframe
    df_robust = df.copy()
    # apply robust scaling
    for column in df_robust.columns:
        df_robust[column] = (df_robust[column] - df_robust[column].median())  / (df_robust[column].quantile(0.75) - df_robust[column].quantile(0.25))
    return df_robust
    
# call the robust_scaling function
df_cars_robust = robust_scaling(df_data)

df_cars_robust
# Out:
#    variable1  variable2
# 0  -1.000000  -1.000000
# 1  -0.714286  -0.714286
# 2  -0.428571  -0.428571
# 3  -0.142857  -0.142857
# 4   0.142857   0.142857
# 5   0.428571   0.428571
# 6   0.714286   0.714286
# 7   7.285714   1.000000

# %%
# Robust Scaling :- Method_2
from sklearn.preprocessing import RobustScaler

# create a scaler object
scaler = RobustScaler()
# fit and transform the data
df_robust = pd.DataFrame(scaler.fit_transform(df_data), columns=df_data.columns)

df_robust
# Out:
#    variable1  variable2
# 0  -1.000000  -1.000000
# 1  -0.714286  -0.714286
# 2  -0.428571  -0.428571
# 3  -0.142857  -0.142857
# 4   0.142857   0.142857
# 5   0.428571   0.428571
# 6   0.714286   0.714286
# 7   7.285714   1.000000

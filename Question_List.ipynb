# %% [markdown]
# 1. Consider a 2D list storing student's name along with their marks. Use list comprehension to create another list comprising names of students with  marks greater than 85.

# %%
def create_dictionary(L):
    new_L = [L[i][:] for i in range(len(L)) if L[i][1] > 85]
    print(new_L)


def input_function():
    number = int(input("Enter the number of elements in list : "))
    L = []
    for i in range(number):
        name = input("Enter Student Name : ")
        marks = int(input("Enter Student Marks : "))
        L.append([name, marks])
    create_dictionary(L)

if __name__ == "__main__":
    input_function()
# Out:
# Enter the number of elements in list : 2
# Enter Student Name : hima
# Enter Student Marks : 99
# Enter Student Name : ran
# Enter Student Marks : 09
# [['hima', 99]]

# %% [markdown]
# 2. WAP that takes a list of marks as an input from the user and creates a dictionary storing marks and the corresponding frequency as key-value pairs.

# %%
def create_dictionary(L):
    set_L = list(set(L))
    set_L.sort()
    print(dict(zip(set_L, [L.count(i) for i in set_L])))


def input_function():
    number = int(input("Enter the number of elements in list : "))
    L = []
    for i in range(number):
        ele = int(input("Enter a element : "))
        L.append(ele)
    create_dictionary(L)


if __name__ == "__main__":
    input_function()
# Out:
# Enter the number of elements in list : 5
# Enter a element : 4
# Enter a element : 7
# Enter a element : 1
# Enter a element : 2
# Enter a element : 3
# {1: 1, 2: 1, 3: 1, 4: 1, 7: 1}

# %% [markdown]
# 3. WAP that takes a list of names as an input from the user and creates a dictionary storing word-length as key-value pair for each word given in the list.

# %%
def create_dictionary(L):
    print(dict(zip(L, [len(i) for i in L])))


def input_function():
    number = int(input("Enter the number of elements in list : "))
    L = []
    for i in range(number):
        ele = input("Enter a element : ")
        L.append(ele)
    create_dictionary(L)

if __name__ == "__main__":
    input_function()
# Out:
# Enter the number of elements in list : 1
# Enter a element : him
# {'him': 3}

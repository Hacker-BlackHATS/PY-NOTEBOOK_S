# %%
from google.colab import drive
drive.mount('/content/drive/')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pract_q2_RuleSet import *

# %%
read_data = pd.read_csv("https://raw.githubusercontent.com/edwindj/datacleaning/master/data/dirty_iris.csv")

# %%
# sum([True for idx,row in read_data.iterrows() if any(row.isnull())])
print(f"Number of observations that are complete : {(read_data.shape[0] - read_data.dropna().shape[0])}")
print(f"Percentage of observations that are complete : {(100*(read_data.shape[0] - read_data.dropna().shape[0])/read_data.shape[0])} %")
# Out:
# Number of observations that are complete : 54
# Percentage of observations that are complete : 36.0 %

# %%
read_data.fillna(value="NA", inplace=True)
read_data.head(5)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width     Species
# 0          6.4         3.2          4.5         1.5  versicolor
# 1          6.3         3.3            6         2.5   virginica
# 2          6.2          NA          5.4         2.3   virginica
# 3            5         3.4          1.6         0.4      setosa
# 4          5.7         2.6          3.5           1  versicolor

# %%
read_data = pd.read_csv("https://raw.githubusercontent.com/edwindj/datacleaning/master/data/dirty_iris.csv")
read_data.dropna(inplace = True)

# %%
result = [E[key](read_data) for key in E.keys()]
# Out:
# No Violation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-06f08e63fbf7> in <module>()
# ----> 1 result = [E[key](read_data) for key in E.keys()]
#
# <ipython-input-7-06f08e63fbf7> in <listcomp>(.0)
# ----> 1 result = [E[key](read_data) for key in E.keys()]
#
# /content/drive/My Drive/Colab Notebooks/pract_q2_RuleSet.py in check_positive_numprop(data_read)
#      13     # rule_2 = lambda npn: (npn[0] > 0) and (npn[1] > 0) and (npn[2] > 0) and (npn[3] > 0)
#      14     rule_2 = lambda npn: npn > 0
# ---> 15     ans = data_read[['Sepal.Length','Sepal.Width', 'Petal.Length', 'Petal.Width']].apply(rule_2, axis=1).rename('check_positive_numprop')
#      16     if np.any(False == ans):
#      17         print('Violation : Measured numerical properties are not positive in some places')
#
# ...

# %%
result1 = [i[1] for i in result]
result1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-92a0f0a58f9d> in <module>()
# ----> 1 result1 = [i[1] for i in result]
#       2 result1
#
# NameError: name 'result' is not defined

# %%
violatedEdits = pd.DataFrame(result)
violatedEdits

# %%
violatedEdits.describe()

# %%
violatedEdits.astype('int').plot(kind='bar');

# %%
import pandas as pd
Df=pd.Series({1:[10,20], 2:[10,20], 3:[30,40]})
Df
# Out:
# 1    [10, 20]
# 2    [10, 20]
# 3    [30, 40]
# dtype: object

# %%
Df.index=(9,8,10)
Df
# Out:
# 9     [10, 20]
# 8     [10, 20]
# 10    [30, 40]
# dtype: object

# %%
Df.reset_index()
# Out:
#    index         0
# 0      9  [10, 20]
# 1      8  [10, 20]
# 2     10  [30, 40]
